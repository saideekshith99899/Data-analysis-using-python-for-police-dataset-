# %%
import pandas as pd

# %%
police = pd.read_csv(r"C:\Users\Sai Deekshith\Downloads\police.csv")

# %%
police
# Out:
#        stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0       1/2/2005      1:55           NaN             M          1985.0
# 1      1/18/2005      8:15           NaN             M          1965.0
# 2      1/23/2005     23:15           NaN             M          1972.0
# 3      2/20/2005     17:15           NaN             M          1986.0
# 4      3/14/2005     10:00           NaN             F          1984.0
# ...          ...       ...           ...           ...             ...
# 65530  12/6/2012     17:54           NaN             F          1987.0
# 65531  12/6/2012     22:22           NaN             M          1954.0
# 65532  12/6/2012     23:20           NaN             M          1985.0
# 65533  12/7/2012      0:23           NaN           NaN             NaN
# 65534  12/7/2012      0:30           NaN             F          1985.0
#
#        driver_age driver_race                   violation_raw  violation  \
# ...

# %%
police.head(10)
# Out:
#    stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0   1/2/2005      1:55           NaN             M          1985.0
# 1  1/18/2005      8:15           NaN             M          1965.0
# 2  1/23/2005     23:15           NaN             M          1972.0
# 3  2/20/2005     17:15           NaN             M          1986.0
# 4  3/14/2005     10:00           NaN             F          1984.0
# 5  3/23/2005      9:45           NaN             M          1982.0
# 6   4/1/2005     17:30           NaN             M          1969.0
# 7   6/6/2005     13:20           NaN             F          1986.0
# 8  7/13/2005     10:15           NaN             M          1970.0
# 9  7/13/2005     15:45           NaN             M          1970.0
#
#    driver_age driver_race                   violation_raw  violation  \
# 0        20.0       White                        Speeding   Speeding
# 1        40.0       White                        Speeding   Speeding
# ...

# %%
police.tail(10)
# Out:
#        stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 65525  12/6/2012     15:09           NaN             M          1980.0
# 65526  12/6/2012     15:22           NaN             M          1982.0
# 65527  12/6/2012     15:26           NaN             F          1981.0
# 65528  12/6/2012     15:39           NaN             M          1987.0
# 65529  12/6/2012     16:00           NaN             M          1994.0
# 65530  12/6/2012     17:54           NaN             F          1987.0
# 65531  12/6/2012     22:22           NaN             M          1954.0
# 65532  12/6/2012     23:20           NaN             M          1985.0
# 65533  12/7/2012      0:23           NaN           NaN             NaN
# 65534  12/7/2012      0:30           NaN             F          1985.0
#
#        driver_age driver_race                   violation_raw  violation  \
# 65525        32.0       White  Equipment/Inspection Violation  Equipment
# ...

# %%
police.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65535 entries, 0 to 65534
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           65535 non-null  object
#  1   stop_time           65535 non-null  object
#  2   country_name        0 non-null      float64
#  3   driver_gender       61474 non-null  object
#  4   driver_age_raw      61481 non-null  float64
#  5   driver_age          61228 non-null  float64
#  6   driver_race         61475 non-null  object
#  7   violation_raw       61475 non-null  object
#  8   violation           61475 non-null  object
#  9   search_conducted    65535 non-null  bool
#  10  search_type         2479 non-null   object
#  11  stop_outcome        61475 non-null  object
#  12  is_arrested         61475 non-null  object
#  13  stop_duration       61475 non-null  object
#  14  drugs_related_stop  65535 non-null  bool
# ...

# %%
police.describe()
# Out:
#        country_name  driver_age_raw    driver_age
# count           0.0    61481.000000  61228.000000
# mean            NaN     1967.791106     34.148984
# std             NaN      121.050106     12.760710
# min             NaN        0.000000     15.000000
# 25%             NaN     1965.000000     23.000000
# 50%             NaN     1978.000000     31.000000
# 75%             NaN     1985.000000     43.000000
# max             NaN     8801.000000     88.000000

# %%
police.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# country_name          65535
# driver_gender          4061
# driver_age_raw         4054
# driver_age             4307
# driver_race            4060
# violation_raw          4060
# violation              4060
# search_conducted          0
# search_type           63056
# stop_outcome           4060
# is_arrested            4060
# stop_duration          4060
# drugs_related_stop        0
# dtype: int64

# %%
police.drop(columns='country_name',inplace=True)

# %%
police
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0        20.0
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 3      2/20/2005     17:15             M          1986.0        19.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# ...          ...       ...           ...             ...         ...
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
# 65532  12/6/2012     23:20             M          1985.0        27.0
# 65533  12/7/2012      0:23           NaN             NaN         NaN
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 0           White                        Speeding   Speeding
# ...

# %%
police.drop(index=0,inplace=True)

# %%
police
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 3      2/20/2005     17:15             M          1986.0        19.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# 5      3/23/2005      9:45             M          1982.0        23.0
# ...          ...       ...           ...             ...         ...
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
# 65532  12/6/2012     23:20             M          1985.0        27.0
# 65533  12/7/2012      0:23           NaN             NaN         NaN
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 1           White                        Speeding   Speeding
# ...

# %%
police.drop(columns = 'search_type',inplace=True)

# %%
police
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 3      2/20/2005     17:15             M          1986.0        19.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# 5      3/23/2005      9:45             M          1982.0        23.0
# ...          ...       ...           ...             ...         ...
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
# 65532  12/6/2012     23:20             M          1985.0        27.0
# 65533  12/7/2012      0:23           NaN             NaN         NaN
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 1           White                        Speeding   Speeding
# ...

# %%
police.shape
# Out:
# (65534, 13)

# %%
police.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65534 entries, 1 to 65534
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           65534 non-null  object
#  1   stop_time           65534 non-null  object
#  2   driver_gender       61473 non-null  object
#  3   driver_age_raw      61480 non-null  float64
#  4   driver_age          61227 non-null  float64
#  5   driver_race         61474 non-null  object
#  6   violation_raw       61474 non-null  object
#  7   violation           61474 non-null  object
#  8   search_conducted    65534 non-null  bool
#  9   stop_outcome        61474 non-null  object
#  10  is_arrested         61474 non-null  object
#  11  stop_duration       61474 non-null  object
#  12  drugs_related_stop  65534 non-null  bool
# dtypes: bool(2), float64(2), object(9)
# memory usage: 5.6+ MB

# %%
police.describe()
# Out:
#        driver_age_raw    driver_age
# count    61480.000000  61227.000000
# mean      1967.790826     34.149215
# std        121.051071     12.760686
# min          0.000000     15.000000
# 25%       1965.000000     23.000000
# 50%       1978.000000     31.000000
# 75%       1985.000000     43.000000
# max       8801.000000     88.000000

# %%
police.violation.value_counts()
# Out:
# Speeding               37203
# Moving violation       11926
# Equipment               6516
# Other                   3583
# Registration/plates     2243
# Seat belt                  3
# Name: violation, dtype: int64

# %%
police[police.violation == 'Speeding']
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# 6       4/1/2005     17:30             M          1969.0        36.0
# 7       6/6/2005     13:20             F          1986.0        19.0
# ...          ...       ...           ...             ...         ...
# 65527  12/6/2012     15:26             F          1981.0        31.0
# 65529  12/6/2012     16:00             M          1994.0        18.0
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race violation_raw violation  search_conducted stop_outcome  \
# ...

# %%
police[police.violation == 'Speeding'].driver_gender.value_counts()
# Out:
# M    25516
# F    11686
# Name: driver_gender, dtype: int64

# %%
police.head(2)
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 1  1/18/2005      8:15             M          1965.0        40.0       White
# 2  1/23/2005     23:15             M          1972.0        33.0       White
#
#   violation_raw violation  search_conducted stop_outcome is_arrested  \
# 1      Speeding  Speeding             False     Citation       False
# 2      Speeding  Speeding             False     Citation       False
#
#   stop_duration  drugs_related_stop
# 1      0-15 Min               False
# 2      0-15 Min               False

# %%
police.groupby('search_conducted')

# %%
police[police.search_conducted == True]
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 24      8/28/2005      1:00             M          1979.0        26.0
# 40      10/1/2005      0:00             M          1988.0        17.0
# 41      10/1/2005      0:00             M          1988.0        17.0
# 80      10/2/2005      9:30             M          1975.0        30.0
# 106     10/3/2005     14:00             M          1978.0        27.0
# ...           ...       ...           ...             ...         ...
# 65254  11/25/2012      0:33             M          1984.0        28.0
# 65358  11/29/2012      1:06             M          1986.0        26.0
# 65408  11/30/2012     22:37             F          1986.0        26.0
# 65409  11/30/2012     23:40             M          1980.0        32.0
# 65499   12/5/2012     23:13             M          1985.0        27.0
#
#       driver_race                   violation_raw         violation  \
# ...

# %%
police.groupby('search_conducted').driver_gender.sum()
# Out:
# search_conducted
# False    MMMFMMFMMMFMFMMMMMFFMMFMFMMMMMMMFMMMMMMMMMMMMM...
# True     MMMMMMMMMFMMMMMMMMMMMMMMMMMMFMMMMMMMMMMMMMMFMF...
# Name: driver_gender, dtype: object

# %%
police.groupby('driver_gender').search_conducted.sum()
# Out:
# driver_gender
# F     366
# M    2113
# Name: search_conducted, dtype: int64

# %%
police.search_conducted.value_counts()
# Out:
# False    63055
# True      2479
# Name: search_conducted, dtype: int64

# %%
police
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 3      2/20/2005     17:15             M          1986.0        19.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# 5      3/23/2005      9:45             M          1982.0        23.0
# ...          ...       ...           ...             ...         ...
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
# 65532  12/6/2012     23:20             M          1985.0        27.0
# 65533  12/7/2012      0:23           NaN             NaN         NaN
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 1           White                        Speeding   Speeding
# ...

# %%
police.stop_duration.value_counts()
# Out:
# 0-15 Min     47378
# 16-30 Min    11448
# 30+ Min       2647
# 2                1
# Name: stop_duration, dtype: int64

# %%
police.stop_duration.unique()
# Out:
# array(['0-15 Min', '16-30 Min', '30+ Min', nan, '2'], dtype=object)

# %%
police.stop_duration.nunique()
# Out:
# 4

# %%
police[police.stop_duration == '0-15 Min']
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# 5      3/23/2005      9:45             M          1982.0        23.0
# 6       4/1/2005     17:30             M          1969.0        36.0
# ...          ...       ...           ...             ...         ...
# 65529  12/6/2012     16:00             M          1994.0        18.0
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
# 65532  12/6/2012     23:20             M          1985.0        27.0
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 1           White                        Speeding   Speeding
# ...

# %%
police[police.stop_duration == '0-15 Min'].driver_gender.value_counts()
# Out:
# M    34165
# F    13212
# Name: driver_gender, dtype: int64

# %%
police['stop_duration'] = police['stop_duration'].map({'0-15 Min':8,'16-30 Min':24,'30+ Min':45,'2':1})

# %%
police
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 3      2/20/2005     17:15             M          1986.0        19.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# 5      3/23/2005      9:45             M          1982.0        23.0
# ...          ...       ...           ...             ...         ...
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
# 65532  12/6/2012     23:20             M          1985.0        27.0
# 65533  12/7/2012      0:23           NaN             NaN         NaN
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 1           White                        Speeding   Speeding
# ...

# %%
police['stop_duration'].mean()
# Out:
# 12.572664866447603

# %%
police.head(2)
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 1  1/18/2005      8:15             M          1965.0        40.0       White
# 2  1/23/2005     23:15             M          1972.0        33.0       White
#
#   violation_raw violation  search_conducted stop_outcome is_arrested  \
# 1      Speeding  Speeding             False     Citation       False
# 2      Speeding  Speeding             False     Citation       False
#
#    stop_duration  drugs_related_stop  stop_durations
# 1            8.0               False             8.0
# 2            8.0               False             8.0

# %%
police.groupby('violation').driver_age.describe()
# Out:
#                        count       mean        std   min   25%   50%   75%  \
# violation
# Equipment             6507.0  31.682957  11.380671  16.0  23.0  28.0  39.0
# Moving violation     11876.0  36.736443  13.258350  15.0  25.0  35.0  47.0
# Other                 3477.0  40.362381  12.754423  16.0  30.0  41.0  50.0
# Registration/plates   2240.0  32.656696  11.150780  16.0  24.0  30.0  40.0
# Seat belt                3.0  30.333333  10.214369  23.0  24.5  26.0  34.0
# Speeding             37119.0  33.262938  12.615764  15.0  23.0  30.0  42.0
#
#                       max
# violation
# Equipment            81.0
# Moving violation     86.0
# Other                86.0
# Registration/plates  74.0
# Seat belt            42.0
# Speeding             88.0

# %%
police.violation.nunique()
# Out:
# 6

# %%
police.groupby('driver_age').violation.describe()
# Out:
#            count unique               top  freq
# driver_age
# 15.0           5      2  Moving violation     4
# 16.0          34      5          Speeding    18
# 17.0         449      5          Speeding   338
# 18.0        1344      5          Speeding   980
# 19.0        2388      5          Speeding  1655
# ...          ...    ...               ...   ...
# 83.0           2      2          Speeding     1
# 84.0           3      1          Speeding     3
# 85.0           1      1  Moving violation     1
# 86.0           6      3          Speeding     3
# 88.0           2      1          Speeding     2
#
# [73 rows x 4 columns]
